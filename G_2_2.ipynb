# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('./data/distances.csv')
df.head()
# Out:
#    Unnamed: 0     Start     Target  Distance
# 0           0  Aberdeen   Aberdeen         0
# 1           1  Aberdeen   Adelaide     16192
# 2           2  Aberdeen    Algiers      2291
# 3           3  Aberdeen  Amsterdam       696
# 4           4  Aberdeen     Ankara      3158

# %%
df.drop("Unnamed: 0", axis=1, inplace=True)
df.head()
# Out:
#       Start     Target  Distance
# 0  Aberdeen   Aberdeen         0
# 1  Aberdeen   Adelaide     16192
# 2  Aberdeen    Algiers      2291
# 3  Aberdeen  Amsterdam       696
# 4  Aberdeen     Ankara      3158

# %%
cities = df['Start'].unique()
print(cities)
# Out:
# ['Aberdeen' 'Adelaide' 'Algiers' 'Amsterdam' 'Ankara' 'Asuncin' 'Athens'
#  'Auckland' 'Bangkok' 'Barcelona' 'Beijing' 'Belm' 'Belfast' 'Belgrade'
#  'Berlin' 'Birmingham' 'Bogot' 'Bombay' 'Bordeaux' 'Bremen' 'Brisbane'
#  'Bristol' 'Brussels' 'Bucharest' 'Budapest' 'Buenos Aires' 'Cairo'
#  'Calcutta' 'Canton' 'Cape Town' 'Caracas' 'Cayenne' 'Chihuahua'
#  'Chongqing' 'Copenhagen' 'Crdoba' 'Dakar' 'Darwin' 'Djibouti' 'Dublin'
#  'Durban' 'Edinburgh' 'Frankfurt' 'Georgetown' 'Glasgow' 'Guatemala City'
#  'Guayaquil' 'Hamburg' 'Hammerfest' 'Havana' 'Helsinki' 'Hobart'
#  'Hong Kong' 'Iquique' 'Irkutsk' 'Jakarta' 'Johannesburg' 'Kingston'
#  'Kinshasa' 'Kuala Lumpur' 'La Paz' 'Leeds' 'Lima' 'Lisbon' 'Liverpool'
#  'London' 'Lyons' 'Madrid' 'Manchester' 'Manila' 'Marseilles' 'Mazatln'
#  'Mecca' 'Melbourne' 'Mexico City' 'Milan' 'Montevideo' 'Moscow' 'Munich'
#  'Nagasaki' 'Nagoya' 'Nairobi' 'Nanjing (Nanking)' 'Naples' 'New Delhi'
#  'Newcastle-on-Tyne' 'Odessa' 'Osaka' 'Oslo' 'Panama City' 'Paramaribo'
#  'Paris' 'Perth' 'Plymouth' 'Port Moresby' 'Prague' 'Rangoon' 'Reykjavk'
#  'Rio de Janeiro' 'Rome' 'Salvador' 'Santiago' 'St. Petersburg' 'So Paulo'
#  'Shanghai' 'Singapore' 'Sofia' 'Stockholm' 'Sydney' 'Tananarive'
#  'Teheran' 'Tokyo' 'Tripoli' 'Venice' 'Veracruz' 'Vienna' 'Vladivostok'
#  'Warsaw' 'Wellington' 'Zrich']

# %%
city_distances_dict = dict(zip(df['Start'] + df['Target'], df['Distance']))
city_distances_dict
# Out:
# {'AberdeenAberdeen': 0,
#  'AberdeenAdelaide': 16192,
#  'AberdeenAlgiers': 2291,
#  'AberdeenAmsterdam': 696,
#  'AberdeenAnkara': 3158,
#  'AberdeenAsuncin': 10521,
#  'AberdeenAthens': 2849,
#  'AberdeenAuckland': 17748,
#  'AberdeenBangkok': 9469,
#  'AberdeenBarcelona': 1779,
#  'AberdeenBeijing': 7796,
#  'AberdeenBelm': 7709,
#  'AberdeenBelfast': 367,
#  'AberdeenBelgrade': 2076,
#  'AberdeenBerlin': 1119,
#  'AberdeenBirmingham': 526,
#  'AberdeenBogot': 8511,
#  'AberdeenBombay': 7339,
#  'AberdeenBordeaux': 1374,
#  'AberdeenBremen': 829,
#  'AberdeenBrisbane': 16186,
#  'AberdeenBristol': 632,
#  'AberdeenBrussels': 817,
#  'AberdeenBucharest': 2411,
#  'AberdeenBudapest': 1785,
#  'AberdeenBuenos Aires': 11476,
#  'AberdeenCairo': 3969,
#  'AberdeenCalcutta': 7948,
#  'AberdeenCanton': 9267,
#  'AberdeenCape Town': 10308,
#  'AberdeenCaracas': 7530,
#  'AberdeenCayenne': 7267,
#  'AberdeenChihuahua': 8148,
#  'AberdeenChongqing': 8292,
#  'AberdeenCopenhagen': 918,
#  'AberdeenCrdoba': 11430,
#  'AberdeenDakar': 4897,
#  'AberdeenDarwin': 13661,
#  'AberdeenDjibouti': 6357,
#  'AberdeenDublin': 497,
#  'AberdeenDurban': 10162,
#  'AberdeenEdinburgh': 150,
#  'AberdeenFrankfurt': 1056,
#  'AberdeenGeorgetown': 7391,
#  'AberdeenGlasgow': 195,
#  'AberdeenGuatemala City': 8548,
#  'AberdeenGuayaquil': 9478,
#  'AberdeenHamburg': 866,
#  'AberdeenHammerfest': 1928,
#  'AberdeenHavana': 7283,
#  'AberdeenHelsinki': 1593,
#  'AberdeenHobart': 17352,
#  'AberdeenHong Kong': 9390,
#  'AberdeenIquique': 10636,
#  'AberdeenIrkutsk': 6121,
#  'AberdeenJakarta': 11728,
#  'AberdeenJohannesburg': 9690,
#  'AberdeenKingston': 7414,
#  'AberdeenKinshasa': 7011,
#  'AberdeenKuala Lumpur': 10541,
#  'AberdeenLa Paz': 10186,
#  'AberdeenLeeds': 380,
#  'AberdeenLima': 10238,
#  'AberdeenLisbon': 2110,
#  'AberdeenLiverpool': 418,
#  'AberdeenLondon': 638,
#  'AberdeenLyons': 1355,
#  'AberdeenMadrid': 1862,
#  'AberdeenManchester': 405,
#  'AberdeenManila': 10486,
#  'AberdeenMarseilles': 1623,
#  'AberdeenMazatln': 8672,
#  'AberdeenMecca': 5214,
#  'AberdeenMelbourne': 16791,
#  'AberdeenMexico City': 8610,
#  'AberdeenMilan': 1515,
#  'AberdeenMontevideo': 11414,
#  'AberdeenMoscow': 2412,
#  'AberdeenMunich': 1360,
#  'AberdeenNagasaki': 9052,
#  'AberdeenNagoya': 9061,
#  'AberdeenNairobi': 7383,
#  'AberdeenNanjing (Nanking)': 8667,
#  'AberdeenNaples': 2160,
#  'AberdeenNew Delhi': 6745,
#  'AberdeenNewcastle-on-Tyne': 245,
#  'AberdeenOdessa': 2524,
#  'AberdeenOsaka': 9074,
#  'AberdeenOslo': 806,
#  'AberdeenPanama City': 8411,
#  'AberdeenParamaribo': 7328,
#  'AberdeenParis': 975,
#  'AberdeenPerth': 14606,
#  'AberdeenPlymouth': 759,
#  'AberdeenPort Moresby': 14087,
#  'AberdeenPrague': 1341,
#  'AberdeenRangoon': 8921,
#  'AberdeenReykjavk': 1318,
#  'AberdeenRio de Janeiro': 9694,
#  'AberdeenRome': 1987,
#  'AberdeenSalvador': 8476,
#  'AberdeenSantiago': 11936,
#  'AberdeenSt. Petersburg': 1888,
#  'AberdeenSo Paulo': 9877,
#  'AberdeenShanghai': 8868,
#  'AberdeenSingapore': 10851,
#  'AberdeenSofia': 2408,
#  'AberdeenStockholm': 1201,
#  'AberdeenSydney': 16743,
#  'AberdeenTananarive': 9619,
#  'AberdeenTeheran': 4602,
#  'AberdeenTokyo': 9093,
#  'AberdeenTripoli': 2933,
#  'AberdeenVenice': 1639,
#  'AberdeenVeracruz': 8463,
#  'AberdeenVienna': 1583,
#  'AberdeenVladivostok': 8072,
#  'AberdeenWarsaw': 1575,
#  'AberdeenWellington': 18237,
#  'AberdeenZrich': 1306,
#  'AdelaideAberdeen': 16192,
#  'AdelaideAdelaide': 0,
#  'AdelaideAlgiers': 16045,
#  'AdelaideAmsterdam': 15908,
#  'AdelaideAnkara': 13621,
#  'AdelaideAsuncin': 13108,
#  'AdelaideAthens': 14301,
#  'AdelaideAuckland': 3244,
#  'AdelaideBangkok': 6739,
#  'AdelaideBarcelona': 16180,
#  'AdelaideBeijing': 8626,
#  'AdelaideBelm': 15902,
#  'AdelaideBelfast': 16521,
#  'AdelaideBelgrade': 14747,
#  'AdelaideBerlin': 15331,
#  'AdelaideBirmingham': 16356,
#  'AdelaideBogot': 15239,
#  'AdelaideBombay': 9167,
#  'AdelaideBordeaux': 16398,
#  'AdelaideBremen': 15634,
#  'AdelaideBrisbane': 1607,
#  'AdelaideBristol': 16429,
#  'AdelaideBrussels': 15968,
#  'AdelaideBucharest': 14305,
#  'AdelaideBudapest': 14902,
#  'AdelaideBuenos Aires': 12088,
#  'AdelaideCairo': 13321,
#  'AdelaideCalcutta': 8298,
#  'AdelaideCanton': 6985,
#  'AdelaideCape Town': 10155,
#  'AdelaideCaracas': 16256,
#  'AdelaideCayenne': 16485,
#  'AdelaideChihuahua': 13964,
#  'AdelaideChongqing': 7937,
#  'AdelaideCopenhagen': 15359,
#  'AdelaideCrdoba': 12259,
#  'AdelaideDakar': 16730,
#  'AdelaideDarwin': 2615,
#  'AdelaideDjibouti': 11237,
#  'AdelaideDublin': 16596,
#  'AdelaideDurban': 9568,
#  'AdelaideEdinburgh': 16303,
#  'AdelaideFrankfurt': 15673,
#  'AdelaideGeorgetown': 16439,
#  'AdelaideGlasgow': 16368,
#  'AdelaideGuatemala City': 14631,
#  'AdelaideGuayaquil': 14262,
#  'AdelaideHamburg': 15548,
#  'AdelaideHammerfest': 14555,
#  'AdelaideHavana': 15853,
#  'AdelaideHelsinki': 14598,
#  'AdelaideHobart': 1160,
#  'AdelaideHong Kong': 6867,
#  'AdelaideIquique': 13180,
#  'AdelaideIrkutsk': 10272,
#  'AdelaideJakarta': 4554,
#  'AdelaideJohannesburg': 10041,
#  'AdelaideKingston': 16048,
#  'AdelaideKinshasa': 12672,
#  'AdelaideKuala Lumpur': 5718,
#  'AdelaideLa Paz': 13632,
#  'AdelaideLeeds': 16286,
#  'AdelaideLima': 13588,
#  'AdelaideLisbon': 17128,
#  'AdelaideLiverpool': 16392,
#  'AdelaideLondon': 16259,
#  'AdelaideLyons': 15977,
#  'AdelaideMadrid': 16666,
#  'AdelaideManchester': 16342,
#  'AdelaideManila': 5810,
#  'AdelaideMarseilles': 15932,
#  'AdelaideMazatln': 13670,
#  'AdelaideMecca': 12129,
#  'AdelaideMelbourne': 653,
#  'AdelaideMexico City': 14134,
#  'AdelaideMilan': 15639,
#  'AdelaideMontevideo': 12103,
#  'AdelaideMoscow': 13803,
#  'AdelaideMunich': 15466,
#  'AdelaideNagasaki': 7583,
#  'AdelaideNagoya': 7789,
#  'AdelaideNairobi': 10978,
#  'AdelaideNanjing (Nanking)': 7725,
#  'AdelaideNaples': 15168,
#  'AdelaideNew Delhi': 9555,
#  'AdelaideNewcastle-on-Tyne': 16250,
#  'AdelaideOdessa': 14008,
#  'AdelaideOsaka': 7729,
#  'AdelaideOslo': 15388,
#  'AdelaidePanama City': 15186,
#  'AdelaideParamaribo': 16474,
#  'AdelaideParis': 16143,
#  'AdelaidePerth': 2130,
#  'AdelaidePlymouth': 16561,
#  'AdelaidePort Moresby': 2965,
#  'AdelaidePrague': 15263,
#  'AdelaideRangoon': 7302,
#  'AdelaideReykjavk': 16515,
#  'AdelaideRio de Janeiro': 13577,
#  'AdelaideRome': 15336,
#  'AdelaideSalvador': 14685,
#  'AdelaideSantiago': 11819,
#  'AdelaideSt. Petersburg': 14303,
#  'AdelaideSo Paulo': 13495,
#  'AdelaideShanghai': 7563,
#  'AdelaideSingapore': 5399,
#  'AdelaideSofia': 14476,
#  'AdelaideStockholm': 14992,
#  'AdelaideSydney': 1140,
#  'AdelaideTananarive': 8915,
#  'AdelaideTeheran': 11934,
#  'AdelaideTokyo': 7849,
#  'AdelaideTripoli': 15036,
#  'AdelaideVenice': 15392,
#  'AdelaideVeracruz': 14388,
#  'AdelaideVienna': 15114,
#  'AdelaideVladivostok': 8708,
#  'AdelaideWarsaw': 14816,
#  'AdelaideWellington': 3219,
#  'AdelaideZrich': 15694,
#  'AlgiersAberdeen': 2291,
#  'AlgiersAdelaide': 16045,
#  'AlgiersAlgiers': 0,
#  'AlgiersAmsterdam': 1733,
#  'AlgiersAnkara': 2617,
#  'AlgiersAsuncin': 9376,
#  'AlgiersAthens': 1830,
#  'AlgiersAuckland': 19281,
#  'AlgiersBangkok': 9746,
#  'AlgiersBarcelona': 511,
#  'AlgiersBeijing': 9108,
#  'AlgiersBelm': 6796,
#  'AlgiersBelfast': 2091,
#  'AlgiersBelgrade': 1718,
#  'AlgiersBerlin': 1922,
#  'AlgiersBirmingham': 1774,
#  'AlgiersBogot': 8571,
#  'AlgiersBombay': 6987,
#  'AlgiersBordeaux': 937,
#  'AlgiersBremen': 1862,
#  'AlgiersBrisbane': 17032,
#  'AlgiersBristol': 1685,
#  'AlgiersBrussels': 1564,
#  'AlgiersBucharest': 2115,
#  'AlgiersBudapest': 1772,
#  'AlgiersBuenos Aires': 10163,
#  'AlgiersCairo': 2725,
#  'AlgiersCalcutta': 8137,
#  'AlgiersCanton': 10131,
#  'AlgiersCape Town': 8026,
#  'AlgiersCaracas': 7540,
#  'AlgiersCayenne': 6639,
#  'AlgiersChihuahua': 9641,
#  'AlgiersChongqing': 9147,
#  'AlgiersCopenhagen': 2214,
#  'AlgiersCrdoba': 10313,
#  'AlgiersDakar': 3190,
#  'AlgiersDarwin': 14178,
#  'AlgiersDjibouti': 4887,
#  'AlgiersDublin': 1969,
#  'AlgiersDurban': 7967,
#  'AlgiersEdinburgh': 2171,
#  'AlgiersFrankfurt': 1545,
#  'AlgiersGeorgetown': 7014,
#  'AlgiersGlasgow': 2181,
#  'AlgiersGuatemala City': 9345,
#  'AlgiersGuayaquil': 9524,
#  'AlgiersHamburg': 1936,
#  'AlgiersHammerfest': 3949,
#  'AlgiersHavana': 8101,
#  'AlgiersHelsinki': 3027,
#  'AlgiersHobart': 16920,
#  'AlgiersHong Kong': 10260,
#  'AlgiersIquique': 9934,
#  'AlgiersIrkutsk': 7525,
#  'AlgiersJakarta': 11651,
#  'AlgiersJohannesburg': 7483,
#  'AlgiersKingston': 7934,
#  'AlgiersKinshasa': 4748,
#  'AlgiersKuala Lumpur': 10569,
#  'AlgiersLa Paz': 9526,
#  'AlgiersLeeds': 1912,
#  'AlgiersLima': 9938,
#  'AlgiersLisbon': 1087,
#  'AlgiersLiverpool': 1901,
#  'AlgiersLondon': 1652,
#  'AlgiersLyons': 1003,
#  'AlgiersMadrid': 706,
#  'AlgiersManchester': 1897,
#  'AlgiersManila': 11369,
#  'AlgiersMarseilles': 749,
#  'AlgiersMazatln': 10061,
#  'AlgiersMecca': 3923,
#  'AlgiersMelbourne': 16673,
#  'AlgiersMexico City': 9746,
#  'AlgiersMilan': 1087,
#  'AlgiersMontevideo': 10047,
#  'AlgiersMoscow': 3332,
#  'AlgiersMunich': 1438,
#  'AlgiersNagasaki': 10515,
#  'AlgiersNagoya': 10705,
#  'AlgiersNairobi': 5506,
#  'AlgiersNanjing (Nanking)': 9867,
#  'AlgiersNaples': 1070,
#  'AlgiersNew Delhi': 6831,
#  'AlgiersNewcastle-on-Tyne': 2046,
#  'AlgiersOdessa': 2528,
#  'AlgiersOsaka': 10681,
#  'AlgiersOslo': 2628,
#  'AlgiersPanama City': 8749,
#  'AlgiersParamaribo': 6824,
#  'AlgiersParis': 1331,
#  'AlgiersPerth': 13958,
#  'AlgiersPlymouth': 1612,
#  'AlgiersPort Moresby': 15295,
#  'AlgiersPrague': 1734,
#  'AlgiersRangoon': 9154,
#  'AlgiersReykjavk': 3456,
#  'AlgiersRio de Janeiro': 8223,
#  'AlgiersRome': 987,
#  'AlgiersSalvador': 7030,
#  'AlgiersSantiago': 10926,
#  'AlgiersSt. Petersburg': 3217,
#  'AlgiersSo Paulo': 8481,
#  'AlgiersShanghai': 10110,
#  'AlgiersSingapore': 10893,
#  'AlgiersSofia': 1849,
#  'AlgiersStockholm': 2720,
#  'AlgiersSydney': 17111,
#  'AlgiersTananarive': 7754,
#  'AlgiersTeheran': 4322,
#  'AlgiersTokyo': 10800,
#  'AlgiersTripoli': 1024,
#  'AlgiersVenice': 1233,
#  'AlgiersVeracruz': 9520,
#  'AlgiersVienna': 1668,
#  'AlgiersVladivostok': 9735,
#  'AlgiersWarsaw': 2216,
#  'AlgiersWellington': 19150,
#  'AlgiersZrich': 1254,
#  'AmsterdamAberdeen': 696,
#  'AmsterdamAdelaide': 15908,
#  'AmsterdamAlgiers': 1733,
#  'AmsterdamAmsterdam': 0,
#  'AmsterdamAnkara': 2540,
#  'AmsterdamAsuncin': 10538,
#  'AmsterdamAthens': 2165,
#  'AmsterdamAuckland': 18118,
#  'AmsterdamBangkok': 9175,
#  'AmsterdamBarcelona': 1238,
#  'AmsterdamBeijing': 7822,
#  'AmsterdamBelm': 7770,
#  'AmsterdamBelfast': 757,
#  'AmsterdamBelgrade': 1416,
#  'AmsterdamBerlin': 578,
#  'AmsterdamBirmingham': 461,
#  'AmsterdamBogot': 8871,
#  'AmsterdamBombay': 6854,
#  'AmsterdamBordeaux': 926,
#  'AmsterdamBremen': 276,
#  'AmsterdamBrisbane': 16201,
#  'AmsterdamBristol': 521,
#  'AmsterdamBrussels': 170,
#  'AmsterdamBucharest': 1790,
#  'AmsterdamBudapest': 1148,
#  'AmsterdamBuenos Aires': 11441,
#  'AmsterdamCairo': 3290,
#  'AmsterdamCalcutta': 7609,
#  'AmsterdamCanton': 9151,
#  'AmsterdamCape Town': 9683,
#  'AmsterdamCaracas': 7863,
#  'AmsterdamCayenne': 7411,
#  'AmsterdamChihuahua': 8805,
#  'AmsterdamChongqing': 8160,
#  'AmsterdamCopenhagen': 621,
#  'AmsterdamCrdoba': 11467,
#  'AmsterdamDakar': 4634,
#  'AmsterdamDarwin': 13499,
#  'AmsterdamDjibouti': 5679,
#  'AmsterdamDublin': 754,
#  'AmsterdamDurban': 9489,
#  'AmsterdamEdinburgh': 655,
#  'AmsterdamFrankfurt': 364,
#  'AmsterdamGeorgetown': 7612,
#  'AmsterdamGlasgow': 708,
#  'AmsterdamGuatemala City': 9085,
#  'AmsterdamGuayaquil': 9847,
#  'AmsterdamHamburg': 369,
#  'AmsterdamHammerfest': 2239,
#  'AmsterdamHavana': 7811,
#  'AmsterdamHelsinki': 1505,
#  'AmsterdamHobart': 17047,
#  'AmsterdamHong Kong': 9278,
#  'AmsterdamIquique': 10803,
#  'AmsterdamIrkutsk': 6164,
#  'AmsterdamJakarta': 11367,
#  'AmsterdamJohannesburg': 9022,
#  'AmsterdamKingston': 7876,
#  'AmsterdamKinshasa': 6377,
#  'AmsterdamKuala Lumpur': 10192,
#  'AmsterdamLa Paz': 10361,
#  'AmsterdamLeeds': 453,
#  'AmsterdamLima': 10522,
#  'AmsterdamLisbon': 1861,
#  'AmsterdamLiverpool': 541,
#  'AmsterdamLondon': 352,
#  'AmsterdamLyons': 735,
#  'AmsterdamMadrid': 1478,
#  'AmsterdamManchester': 494,
#  'AmsterdamManila': 10391,
#  'AmsterdamMarseilles': 1005,
#  'AmsterdamMazatln': 9317,
#  'AmsterdamMecca': 4544,
#  'AmsterdamMelbourne': 16545,
#  'AmsterdamMexico City': 9214,
#  'AmsterdamMilan': 829,
#  'AmsterdamMontevideo': 11358,
#  'AmsterdamMoscow': 2147,
#  'AmsterdamMunich': 669,
#  'AmsterdamNagasaki': 9150,
#  'AmsterdamNagoya': 9234,
#  'AmsterdamNairobi': 6687,
#  'AmsterdamNanjing (Nanking)': 8661,
#  'AmsterdamNaples': 1465,
#  'AmsterdamNew Delhi': 6359,
#  'AmsterdamNewcastle-on-Tyne': 516,
#  'AmsterdamOdessa': 1974,
#  'AmsterdamOsaka': 9231,
#  'AmsterdamOslo': 916,
#  'AmsterdamPanama City': 8840,
#  'AmsterdamParamaribo': 7511,
#  'AmsterdamParis': 435,
#  'AmsterdamPerth': 14144,
#  'AmsterdamPlymouth': 658,
#  'AmsterdamPort Moresby': 14154,
#  'AmsterdamPrague': 711,
#  'AmsterdamRangoon': 8607,
#  'AmsterdamReykjavk': 2014,
#  'AmsterdamRio de Janeiro': 9581,
#  'AmsterdamRome': 1295,
#  'AmsterdamSalvador': 8360,
#  'AmsterdamSantiago': 12017,
#  'AmsterdamSt. Petersburg': 1769,
#  'AmsterdamSo Paulo': 9795,
#  'AmsterdamShanghai': 8880,
#  'AmsterdamSingapore': 10510,
#  'AmsterdamSofia': 1747,
#  'AmsterdamStockholm': 1122,
#  'AmsterdamSydney': 16642,
#  'AmsterdamTananarive': 8923,
#  'AmsterdamTeheran': 4083,
#  'AmsterdamTokyo': 9293,
#  'AmsterdamTripoli': 2260,
#  'AmsterdamVenice': 942,
#  'AmsterdamVeracruz': 9051,
#  'AmsterdamVienna': 932,
#  'AmsterdamVladivostok': 8245,
#  'AmsterdamWarsaw': 1093,
#  'AmsterdamWellington': 18565,
#  'AmsterdamZrich': 615,
#  'AnkaraAberdeen': 3158,
#  'AnkaraAdelaide': 13621,
#  'AnkaraAlgiers': 2617,
#  'AnkaraAmsterdam': 2540,
#  'AnkaraAnkara': 0,
#  'AnkaraAsuncin': 11820,
#  'AnkaraAthens': 824,
#  'AnkaraAuckland': 16696,
#  'AnkaraBangkok': 7128,
#  'AnkaraBarcelona': 2587,
#  'AnkaraBeijing': 6829,
#  'AnkaraBelm': 9380,
#  'AnkaraBelfast': 3297,
#  'AnkaraBelgrade': 1154,
#  'AnkaraBerlin': 2039,
#  'AnkaraBirmingham': 2981,
#  'AnkaraBogot': 11127,
#  'AnkaraBombay': 4454,
#  'AnkaraBordeaux': 2779,
#  'AnkaraBremen': 2335,
#  'AnkaraBrisbane': 14420,
#  'AnkaraBristol': 3003,
#  'AnkaraBrussels': 2517,
#  'AnkaraBucharest': 750,
#  'AnkaraBudapest': 1392,
#  'AnkaraBuenos Aires': 12479,
#  'AnkaraCairo': 1108,
#  'AnkaraCalcutta': 5519,
#  'AnkaraCanton': 7590,
#  'AnkaraCape Town': 8344,
#  'AnkaraCaracas': 10095,
#  'AnkaraCayenne': 9256,
#  'AnkaraChihuahua': 11295,
#  'AnkaraChongqing': 6627,
#  'AnkaraCopenhagen': 2301,
#  'AnkaraCrdoba': 12738,
#  'AnkaraDakar': 5619,
#  'AnkaraDarwin': 11564,
#  'AnkaraDjibouti': 3313,
#  'AnkaraDublin': 3287,
#  'AnkaraDurban': 7764,
#  'AnkaraEdinburgh': 3169,
#  'AnkaraFrankfurt': 2202,
#  'AnkaraGeorgetown': 9625,
#  'AnkaraGlasgow': 3230,
#  'AnkaraGuatemala City': 11597,
#  'AnkaraGuayaquil': 12095,
#  'AnkaraHamburg': 2292,
#  'AnkaraHammerfest': 3456,
#  'AnkaraHavana': 10321,
#  'AnkaraHelsinki': 2317,
#  'AnkaraHobart': 14674,
#  'AnkaraHong Kong': 7718,
#  'AnkaraIquique': 12515,
#  'AnkaraIrkutsk': 5433,
#  'AnkaraJakarta': 9102,
#  'AnkaraJohannesburg': 7368,
#  'AnkaraKingston': 10314,
#  'AnkaraKinshasa': 5236,
#  'AnkaraKuala Lumpur': 7984,
#  'AnkaraLa Paz': 12120,
#  'AnkaraLeeds': 2993,
#  'AnkaraLima': 12555,
#  'AnkaraLisbon': 3587,
#  'AnkaraLiverpool': 3079,
#  'AnkaraLondon': 2836,
#  'AnkaraLyons': 2366,
#  'AnkaraMadrid': 3088,
#  'AnkaraManchester': 3033,
#  'AnkaraManila': 8808,
#  'AnkaraMarseilles': 2313,
#  'AnkaraMazatln': 11828,
#  'AnkaraMecca': 2149,
#  'AnkaraMelbourne': 14273,
#  'AnkaraMexico City': 11754,
#  'AnkaraMilan': 2027,
#  'AnkaraMontevideo': 12332,
#  'AnkaraMoscow': 1793,
#  'AnkaraMunich': 1925,
#  'AnkaraNagasaki': 8274,
#  'AnkaraNagoya': 8612,
#  'AnkaraNairobi': 4614,
#  'AnkaraNanjing (Nanking)': 7481,
#  'AnkaraNaples': 1581,
#  'AnkaraNew Delhi': 4213,
#  'AnkaraNewcastle-on-Tyne': 3042,
#  'AnkaraOdessa': 746,
#  'AnkaraOsaka': 8554,
#  'AnkaraOslo': 2708,
#  'AnkaraPanama City': 11220,
#  'AnkaraParamaribo': 9441,
#  'AnkaraParis': 2602,
#  'AnkaraPerth': 11681,
#  'AnkaraPlymouth': 3087,
#  'AnkaraPort Moresby': 12736,
#  'AnkaraPrague': 1832,
#  'AnkaraRangoon': 6537,
#  'AnkaraReykjavk': 4408,
#  'AnkaraRio de Janeiro': 10522,
#  'AnkaraRome': 1729,
#  'AnkaraSalvador': 9399,
#  'AnkaraSantiago': 13380,
#  'AnkaraSt. Petersburg': 2233,
#  'AnkaraSo Paulo': 10819,
#  'AnkaraShanghai': 7738,
#  'AnkaraSingapore': 8309,
#  'AnkaraSofia': 856,
#  'AnkaraStockholm': 2392,
#  'AnkaraSydney': 14584,
#  'AnkaraTananarive': 6706,
#  'AnkaraTeheran': 1713,
#  'AnkaraTokyo': 8765,
#  'AnkaraTripoli': 1921,
#  'AnkaraVenice': 1784,
#  'AnkaraVeracruz': 11591,
#  'AnkaraVienna': 1610,
#  'AnkaraVladivostok': 7724,
#  'AnkaraWarsaw': 1644,
#  'AnkaraWellington': 16817,
#  'AnkaraZrich': 2119,
#  'AsuncinAberdeen': 10521,
#  'AsuncinAdelaide': 13108,
#  'AsuncinAlgiers': 9376,
#  'AsuncinAmsterdam': 10538,
#  'AsuncinAnkara': 11820,
#  'AsuncinAsuncin': 0,
#  'AsuncinAthens': 11002,
#  'AsuncinAuckland': 11195,
#  'AsuncinBangkok': 17399,
#  'AsuncinBarcelona': 9630,
#  'AsuncinBeijing': 18293,
#  'AsuncinBelm': 2822,
#  'AsuncinBelfast': 10156,
#  'AsuncinBelgrade': 11094,
#  'AsuncinBerlin': 11030,
#  'AsuncinBirmingham': 10183,
#  'AsuncinBogot': 3764,
#  'AsuncinBombay': 14893,
#  'AsuncinBordeaux': 9706,
#  'AsuncinBremen': 10801,
#  'AsuncinBrisbane': 13287,
#  'AsuncinBristol': 10078,
#  'AsuncinBrussels': 10410,
#  'AsuncinBucharest': 11476,
#  'AsuncinBudapest': 11124,
#  'AsuncinBuenos Aires': 1040,
#  'AsuncinCairo': 11290,
#  'AsuncinCalcutta': 16561,
#  'AsuncinCanton': 19063,
#  'AsuncinCape Town': 7251,
#  'AsuncinCaracas': 4099,
#  'AsuncinCayenne': 3393,
#  'AsuncinChihuahua': 7914,
#  'AsuncinChongqing': 18382,
#  'AsuncinCopenhagen': 11158,
#  'AsuncinCrdoba': 938,
#  'AsuncinDakar': 6218,
#  'AsuncinDarwin': 15720,
#  'AsuncinDjibouti': 11616,
#  'AsuncinDublin': 10041,
#  'AsuncinDurban': 8513,
#  'AsuncinEdinburgh': 10383,
#  'AsuncinFrankfurt': 10611,
#  'AsuncinGeorgetown': 3558,
#  'AsuncinGlasgow': 10327,
#  'AsuncinGuatemala City': 5685,
#  'AsuncinGuayaquil': 3503,
#  'AsuncinHamburg': 10897,
#  'AsuncinHammerfest': 12333,
#  'AsuncinHavana': 6003,
#  'AsuncinHelsinki': 12033,
#  'AsuncinHobart': 12020,
#  'AsuncinHong Kong': 19124,
#  'AsuncinIquique': 1395,
#  'AsuncinIrkutsk': 16629,
#  'AsuncinJakarta': 16128,
#  'AsuncinJohannesburg': 8406,
#  'AsuncinKingston': 5235,
#  'AsuncinKinshasa': 8090,
#  'AsuncinKuala Lumpur': 16710,
#  'AsuncinLa Paz': 1479,
#  'AsuncinLeeds': 10302,
#  'AsuncinLima': 2511,
#  'AsuncinLisbon': 8721,
#  'AsuncinLiverpool': 10203,
#  'AsuncinLondon': 10213,
#  'AsuncinLyons': 10097,
#  'AsuncinMadrid': 9187,
#  'AsuncinManchester': 10246,
#  'AsuncinManila': 18820,
#  'AsuncinMarseilles': 9969,
#  'AsuncinMazatln': 7523,
#  'AsuncinMecca': 11715,
#  'AsuncinMelbourne': 12618,
#  'AsuncinMexico City': 6690,
#  'AsuncinMilan': 10354,
#  'AsuncinMontevideo': 1080,
#  'AsuncinMoscow': 12624,
#  'AsuncinMunich': 10670,
#  'AsuncinNagasaki': 18896,
#  'AsuncinNagoya': 18237,
#  'AsuncinNairobi': 10400,
#  'AsuncinNanjing (Nanking)': 19187,
#  'AsuncinNaples': 10431,
#  'AsuncinNew Delhi': 15550,
#  'AsuncinNewcastle-on-Tyne': 10385,
#  'AsuncinOdessa': 11898,
#  'AsuncinOsaka': 18381,
#  'AsuncinOslo': 11305,
#  'AsuncinPanama City': 4481,
#  'AsuncinParamaribo': 3456,
#  'AsuncinParis': 10154,
#  'AsuncinPerth': 13617,
#  'AsuncinPlymouth': 9922,
#  'AsuncinPort Moresby': 15316,
#  'AsuncinPrague': 10959,
#  'AsuncinRangoon': 17132,
#  'AsuncinReykjavk': 10405,
#  'AsuncinRio de Janeiro': 1489,
#  'AsuncinRome': 10363,
#  'AsuncinSalvador': 2434,
#  'AsuncinSantiago': 1560,
#  'AsuncinSt. Petersburg': 12306,
#  'AsuncinSo Paulo': 1145,
#  'AsuncinShanghai': 19351,
#  'AsuncinSingapore': 16693,
#  'AsuncinSofia': 11193,
#  'AsuncinStockholm': 11635,
#  'AsuncinSydney': 12764,
#  'AsuncinTananarive': 10562,
#  'AsuncinTeheran': 13293,
#  'AsuncinTokyo': 17988,
#  'AsuncinTripoli': 9900,
#  'AsuncinVenice': 10561,
#  'AsuncinVeracruz': 6459,
#  'AsuncinVienna': 10980,
#  'AsuncinVladivostok': 17837,
#  'AsuncinWarsaw': 11475,
#  'AsuncinWellington': 10855,
#  'AsuncinZrich': 10430,
#  'AthensAberdeen': 2849,
#  'AthensAdelaide': 14301,
#  'AthensAlgiers': 1830,
#  'AthensAmsterdam': 2165,
#  'AthensAnkara': 824,
#  'AthensAsuncin': 11002,
#  'AthensAthens': 0,
#  'AthensAuckland': 17464,
#  'AthensBangkok': 7923,
#  'AthensBarcelona': 1879,
#  'AthensBeijing': 7618,
#  'AthensBelm': 8560,
#  'AthensBelfast': 2898,
#  'AthensBelgrade': 811,
#  'AthensBerlin': 1801,
#  'AthensBirmingham': 2548,
#  'AthensBogot': 10391,
#  'AthensBombay': 5169,
#  'AthensBordeaux': 2150,
#  'AthensBremen': 2033,
#  'AthensBrisbane': 15202,
#  'AthensBristol': 2540,
#  'AthensBrussels': 2090,
#  'AthensBucharest': 744,
#  'AthensBudapest': 1125,
#  'AthensBuenos Aires': 11681,
#  'AthensCairo': 1127,
#  'AthensCalcutta': 6317,
#  'AthensCanton': 8414,
#  'AthensCape Town': 8012,
#  'AthensCaracas': 9359,
#  'AthensCayenne': 8453,
#  'AthensChihuahua': 10956,
#  'AthensChongqing': 7450,
#  'AthensCopenhagen': 2137,
#  'AthensCrdoba': 11924,
#  'AthensDakar': 4796,
#  'AthensDarwin': 12350,
#  'AthensDjibouti': 3514,
#  'AthensDublin': 2854,
#  'AthensDurban': 7581,
#  'AthensEdinburgh': 2820,
#  'AthensFrankfurt': 1801,
#  'AthensGeorgetown': 8843,
#  'AthensGlasgow': 2872,
#  'AthensGuatemala City': 11017,
#  'AthensGuayaquil': 11350,
#  'AthensHamburg': 2024,
#  'AthensHammerfest': 3632,
#  'AthensHavana': 9748,
#  'AthensHelsinki': 2470,
#  'AthensHobart': 15298,
#  'AthensHong Kong': 8543,
#  'AthensIquique': 11693,
#  'AthensIrkutsk': 6171,
#  'AthensJakarta': 9834,
#  'AthensJohannesburg': 7149,
#  'AthensKingston': 9670,
#  'AthensKinshasa': 4779,
#  'AthensKuala Lumpur': 8740,
#  'AthensLa Paz': 11301,
#  'AthensLeeds': 2600,
#  'AthensLima': 11760,
#  'AthensLisbon': 2851,
#  'AthensLiverpool': 2666,
#  'AthensLondon': 2391,
#  'AthensLyons': 1781,
#  'AthensMadrid': 2368,
#  'AthensManchester': 2627,
#  'AthensManila': 9632,
#  'AthensMarseilles': 1657,
#  'AthensMazatln': 11451,
#  'AthensMecca': 2391,
#  'AthensMelbourne': 14948,
#  'AthensMexico City': 11280,
#  'AthensMilan': 1463,
#  'AthensMontevideo': 11540,
#  'AthensMoscow': 2232,
#  'AthensMunich': 1496,
#  'AthensNagasaki': 9061,
#  'AthensNagoya': 9371,
#  'AthensNairobi': 4584,
#  'AthensNanjing (Nanking)': 8290,
#  'AthensNaples': 873,
#  'AthensNew Delhi': 5011,
#  'AthensNewcastle-on-Tyne': 2680,
#  'AthensOdessa': 1108,
#  'AthensOsaka': 9319,
#  'AthensOslo': 2611,
#  'AthensPanama City': 10534,
#  'AthensParamaribo': 8648,
#  'AthensParis': 2094,
#  'AthensPerth': 12290,
#  'AthensPlymouth': 2589,
#  'AthensPort Moresby': 13558,
#  'AthensPrague': 1535,
#  'AthensRangoon': 7331,
#  'AthensReykjavk': 4161,
#  'AthensRio de Janeiro': 9722,
#  'AthensRome': 1054,
#  'AthensSalvador': 8587,
#  'AthensSantiago': 12563,
#  'AthensSt. Petersburg': 2486,
#  'AthensSo Paulo': 10013,
#  'AthensShanghai': 8545,
#  'AthensSingapore': 9065,
#  'AthensSofia': 523,
#  'AthensStockholm': 2404,
#  'AthensSydney': 15314,
#  'AthensTananarive': 6789,
#  'AthensTeheran': 2496,
#  'AthensTokyo': 9512,
#  'AthensTripoli': 1102,
#  'AthensVenice': 1255,
#  'AthensVeracruz': 11089,
#  'AthensVienna': 1287,
#  'AthensVladivostok': 8460,
#  'AthensWarsaw': 1600,
#  'AthensWellington': 17521,
#  'AthensZrich': 1617,
#  'AucklandAberdeen': 17748,
#  'AucklandAdelaide': 3244,
#  'AucklandAlgiers': 19281,
#  'AucklandAmsterdam': 18118,
#  'AucklandAnkara': 16696,
#  'AucklandAsuncin': 11195,
#  'AucklandAthens': 17464,
#  'AucklandAuckland': 0,
#  'AucklandBangkok': 9571,
#  'AucklandBarcelona': 19203,
#  'AucklandBeijing': 10408,
#  'AucklandBelm': 13850,
#  'AucklandBelfast': 18040,
#  'AucklandBelgrade': 17684,
#  'AucklandBerlin': 17748,
#  'AucklandBirmingham': 18266,
#  'AucklandBogot': 12171,
#  'AucklandBombay': 12298,
#  'AucklandBordeaux': 19044,
#  'AucklandBremen': 17907,
#  'AucklandBrisbane': 2278,
#  'AucklandBristol': 18378,
#  'AucklandBrussels': 18281,
#  'AucklandBucharest': 17258,
#  'AucklandBudapest': 17701,
#  'AucklandBuenos Aires': 10356,
#  'AucklandCairo': 16557,
#  'AucklandCalcutta': 11181,
#  'AucklandCanton': 9269,
#  'AucklandCape Town': 11772,
#  'AucklandCaracas': 13204,
#  'AucklandCayenne': 14056,
#  'AucklandChihuahua': 11001,
#  'AucklandChongqing': 10260,
#  'AucklandCopenhagen': 17532,
#  'AucklandCrdoba': 10256,
#  'AucklandDakar': 17266,
#  'AucklandDarwin': 5135,
#  'AucklandDjibouti': 14441,
#  'AucklandDublin': 18182,
#  'AucklandDurban': 11691,
#  'AucklandEdinburgh': 17891,
#  'AucklandFrankfurt': 18168,
#  'AucklandGeorgetown': 13707,
#  'AucklandGlasgow': 17904,
#  'AucklandGuatemala City': 11389,
#  'AucklandGuayaquil': 11215,
#  'AucklandHamburg': 17817,
#  'AucklandHammerfest': 15897,
#  'AucklandHavana': 12626,
#  'AucklandHelsinki': 16656,
#  'AucklandHobart': 2422,
#  'AucklandHong Kong': 9140,
#  'AucklandIquique': 10723,
#  'AucklandIrkutsk': 12033,
#  'AucklandJakarta': 7633,
#  'AucklandJohannesburg': 12183,
#  'AucklandKingston': 12810,
#  'AucklandKinshasa': 14966,
#  'AucklandKuala Lumpur': 8724,
#  'AucklandLa Paz': 11141,
#  'AucklandLeeds': 18115,
#  'AucklandLima': 10773,
#  'AucklandLisbon': 19614,
#  'AucklandLiverpool': 18166,
#  'AucklandLondon': 18334,
#  'AucklandLyons': 18719,
#  'AucklandMadrid': 19596,
#  'AucklandManchester': 18151,
#  'AucklandManila': 8024,
#  'AucklandMarseilles': 18864,
#  'AucklandMazatln': 10606,
#  'AucklandMecca': 15373,
#  'AucklandMelbourne': 2624,
#  'AucklandMexico City': 10958,
#  'AucklandMilan': 18480,
#  'AucklandMontevideo': 10457,
#  'AucklandMoscow': 16200,
#  'AucklandMunich': 18158,
#  'AucklandNagasaki': 9034,
#  'AucklandNagoya': 8907,
#  'AucklandNairobi': 13933,
#  'AucklandNanjing (Nanking)': 9611,
#  'AucklandNaples': 18273,
#  'AucklandNew Delhi': 12486,
#  'AucklandNewcastle-on-Tyne': 17983,
#  'AucklandOdessa': 16868,
#  'AucklandOsaka': 8917,
#  'AucklandOslo': 17208,
#  'AucklandPanama City': 11999,
#  'AucklandParamaribo': 13885,
#  'AucklandParis': 18552,
#  'AucklandPerth': 5344,
#  'AucklandPlymouth': 18505,
#  'AucklandPort Moresby': 4126,
#  'AucklandPrague': 17863,
#  'AucklandRangoon': 10162,
#  'AucklandReykjavk': 16790,
#  'AucklandRio de Janeiro': 12265,
#  'AucklandRome': 18397,
#  'AucklandSalvador': 13477,
#  'AucklandSantiago': 9662,
#  'AucklandSt. Petersburg': 16424,
#  'AucklandSo Paulo': 12029,
#  'AucklandShanghai': 9377,
#  'AucklandSingapore': 8399,
#  'AucklandSofia': 17501,
#  'AucklandStockholm': 17014,
#  'AucklandSydney': 2169,
#  'AucklandTananarive': 11710,
#  'AucklandTeheran': 14984,
#  'AucklandTokyo': 8837,
#  'AucklandTripoli': 18280,
#  'AucklandVenice': 18267,
#  'AucklandVeracruz': 11192,
#  'AucklandVienna': 17854,
#  'AucklandVladivostok': 9892,
#  'AucklandWarsaw': 17349,
#  'AucklandWellington': 491,
#  'AucklandZrich': 18392,
#  'BangkokAberdeen': 9469,
#  'BangkokAdelaide': 6739,
#  'BangkokAlgiers': 9746,
#  'BangkokAmsterdam': 9175,
#  'BangkokAnkara': 7128,
#  'BangkokAsuncin': 17399,
#  'BangkokAthens': 7923,
#  'BangkokAuckland': 9571,
#  'BangkokBangkok': 0,
#  'BangkokBarcelona': 9680,
#  'BangkokBeijing': 3298,
#  'BangkokBelm': 16340,
#  'BangkokBelfast': 9786,
#  'BangkokBelgrade': 8148,
#  'BangkokBerlin': 8603,
#  'BangkokBirmingham': 9618,
#  'BangkokBogot': 17901,
#  'BangkokBombay': 3008,
#  'BangkokBordeaux': 9778,
#  'BangkokBremen': 8900,
#  'BangkokBrisbane': 7293,
#  'BangkokBristol': 9695,
#  'BangkokBrussels': 9248,
#  'BangkokBucharest': 7708,
#  'BangkokBudapest': 8244,
#  'BangkokBuenos Aires': 16873,
#  'BangkokCairo': 7258,
#  'BangkokCalcutta': 1609,
#  'BangkokCanton': 1699,
#  'BangkokCape Town': 10149,
#  'BangkokCaracas': 16991,
#  'BangkokCayenne': 16372,
#  'BangkokChihuahua': 14504,
#  'BangkokChongqing': 1886,
#  'BangkokCopenhagen': 8620,
#  'BangkokCrdoba': 17499,
#  'BangkokDakar': 12494,
#  'BangkokDarwin': 4436,
#  'BangkokDjibouti': 6224,
#  'BangkokDublin': 9857,
#  ...}

# %%
len(city_distances_dict)
# Out:
# 14400

# %% [markdown]
# # I use shuffle for time complexity optimization (instead of randomize each city, one at the time) Each shuffle is independent from eachother.

# %%
def all_cities_visited_simulation(cities, cities_dict):
    np.random.shuffle(cities)
    total_distance = 0
    start = None
    target = None
    
    for city in cities:
        if not (start):
            start = city
            continue
     
        target = city
        total_distance += cities_dict[start + target]
        start = target
        target = None
    return total_distance

# %%
distances = [all_cities_visited_simulation(cities, city_distances_dict) for i in range(10000)]
distances
# Out:
# [873542,
#  991034,
#  1000718,
#  964672,
#  1048434,
#  992830,
#  955175,
#  981902,
#  966796,
#  1022706,
#  927334,
#  1069878,
#  982912,
#  915584,
#  968467,
#  990791,
#  1026818,
#  955651,
#  1016108,
#  1002428,
#  952000,
#  939624,
#  921796,
#  946924,
#  954712,
#  1000274,
#  1021655,
#  979167,
#  1009215,
#  1056604,
#  954903,
#  923188,
#  905557,
#  1017787,
#  945618,
#  928006,
#  980544,
#  959713,
#  1002929,
#  940441,
#  916953,
#  1008740,
#  1025350,
#  1014358,
#  986996,
#  1008514,
#  921276,
#  922170,
#  1000785,
#  922307,
#  987110,
#  1015964,
#  977475,
#  993855,
#  999040,
#  1025851,
#  959967,
#  969308,
#  946161,
#  985792,
#  1006288,
#  967974,
#  998568,
#  930730,
#  965919,
#  987245,
#  999902,
#  965308,
#  1016009,
#  976261,
#  1003745,
#  992320,
#  1082680,
#  1003885,
#  1003833,
#  1002913,
#  972649,
#  967602,
#  991662,
#  1085627,
#  931539,
#  1006472,
#  977423,
#  904144,
#  1043593,
#  1017297,
#  980116,
#  900327,
#  961229,
#  949873,
#  1018821,
#  940011,
#  907998,
#  945255,
#  1026933,
#  1000402,
#  939748,
#  1033027,
#  909303,
#  1014902,
#  979919,
#  1012637,
#  1001831,
#  938180,
#  1027046,
#  1028405,
#  938712,
#  965791,
#  969873,
#  1000372,
#  912838,
#  1019775,
#  894707,
#  1044027,
#  913130,
#  1025493,
#  980690,
#  1020389,
#  1002984,
#  1038971,
#  976904,
#  965090,
#  1026189,
#  947090,
#  986995,
#  1055907,
#  983169,
#  933003,
#  1078781,
#  991173,
#  1038477,
#  1031939,
#  973247,
#  1023925,
#  1001052,
#  961414,
#  962476,
#  1026527,
#  872415,
#  961417,
#  1010693,
#  1044626,
#  993569,
#  1050943,
#  948303,
#  953622,
#  1016999,
#  1041220,
#  996635,
#  930285,
#  1027265,
#  975167,
#  1029775,
#  1015830,
#  1020744,
#  1010973,
#  1011446,
#  963409,
#  1008172,
#  1034531,
#  952846,
#  929877,
#  1003835,
#  902187,
#  977823,
#  987870,
#  993761,
#  922218,
#  923030,
#  943482,
#  950804,
#  926706,
#  931591,
#  879082,
#  966304,
#  964828,
#  982709,
#  968066,
#  926401,
#  963276,
#  913210,
#  960677,
#  936160,
#  994851,
#  1055220,
#  946753,
#  1078546,
#  924376,
#  1044003,
#  988450,
#  991276,
#  933833,
#  997639,
#  998018,
#  952325,
#  1034433,
#  968999,
#  912387,
#  1036105,
#  1003170,
#  1012542,
#  974005,
#  942034,
#  973304,
#  993067,
#  985113,
#  1000945,
#  991935,
#  1008982,
#  986517,
#  1026629,
#  1021529,
#  975733,
#  975465,
#  1006711,
#  955837,
#  962248,
#  988262,
#  1013538,
#  1033416,
#  988966,
#  932540,
#  971613,
#  930402,
#  1020217,
#  998733,
#  1046680,
#  971415,
#  1124910,
#  1013038,
#  951805,
#  1004317,
#  1061409,
#  1027606,
#  982994,
#  1064100,
#  1001471,
#  971909,
#  970867,
#  1018821,
#  972334,
#  1083101,
#  1046297,
#  1059394,
#  947562,
#  973266,
#  966358,
#  900550,
#  985595,
#  985355,
#  989095,
#  953536,
#  1015219,
#  1004633,
#  907469,
#  1073241,
#  949329,
#  1011745,
#  997005,
#  937835,
#  1034087,
#  942981,
#  1026426,
#  947800,
#  976998,
#  1005973,
#  1062042,
#  1021555,
#  974983,
#  1045577,
#  1000347,
#  1020532,
#  1012025,
#  1013871,
#  982490,
#  903495,
#  1002749,
#  968337,
#  940915,
#  1006307,
#  1014263,
#  971215,
#  1049795,
#  1014791,
#  992422,
#  969425,
#  941660,
#  993792,
#  1011824,
#  1044223,
#  1011188,
#  913940,
#  1051995,
#  985457,
#  1020291,
#  933995,
#  1022878,
#  956879,
#  975929,
#  984026,
#  960070,
#  967435,
#  967710,
#  942434,
#  999428,
#  1000948,
#  980718,
#  988509,
#  1044955,
#  1002549,
#  916541,
#  993737,
#  1027592,
#  986008,
#  977794,
#  973535,
#  984645,
#  986332,
#  970032,
#  965454,
#  1017683,
#  1015330,
#  910791,
#  1053187,
#  939284,
#  971829,
#  1032248,
#  994819,
#  993338,
#  1019013,
#  964237,
#  942593,
#  1037426,
#  915088,
#  1068599,
#  960592,
#  1007108,
#  966859,
#  1035969,
#  898385,
#  1078872,
#  1039794,
#  936981,
#  956107,
#  944046,
#  986625,
#  1023087,
#  973571,
#  999820,
#  977459,
#  937171,
#  1003735,
#  1004594,
#  1005831,
#  1003360,
#  1013342,
#  999959,
#  940691,
#  998902,
#  965442,
#  1074929,
#  1043081,
#  931837,
#  1015521,
#  1050987,
#  916648,
#  950011,
#  966409,
#  999112,
#  926068,
#  969578,
#  922737,
#  969079,
#  982297,
#  931288,
#  1022066,
#  954474,
#  999248,
#  1040111,
#  960764,
#  1009399,
#  967920,
#  963093,
#  945500,
#  995966,
#  1012938,
#  960418,
#  982480,
#  986856,
#  1008981,
#  948722,
#  956683,
#  962341,
#  1001996,
#  1050829,
#  992327,
#  917872,
#  1007940,
#  912733,
#  989253,
#  960533,
#  997411,
#  1072518,
#  1001042,
#  971356,
#  955444,
#  909048,
#  1075549,
#  1007531,
#  1008540,
#  948069,
#  966224,
#  978342,
#  882343,
#  1058935,
#  1009710,
#  927092,
#  960816,
#  982589,
#  1053660,
#  954022,
#  979268,
#  949360,
#  937818,
#  974305,
#  951565,
#  1005602,
#  972536,
#  1022137,
#  970003,
#  976563,
#  970898,
#  977707,
#  963235,
#  915384,
#  869212,
#  974157,
#  925988,
#  984457,
#  950602,
#  945177,
#  909920,
#  1040344,
#  1001660,
#  995898,
#  942855,
#  1026141,
#  973777,
#  1016961,
#  993152,
#  964377,
#  1023281,
#  971219,
#  955028,
#  961957,
#  1017768,
#  965307,
#  886673,
#  915069,
#  1051543,
#  955820,
#  940394,
#  925633,
#  991640,
#  952659,
#  960535,
#  992279,
#  993232,
#  946607,
#  874652,
#  1002867,
#  959626,
#  1024253,
#  977467,
#  992976,
#  1032451,
#  961150,
#  950474,
#  1007330,
#  1010908,
#  924876,
#  1007153,
#  925237,
#  983515,
#  964830,
#  977250,
#  939187,
#  986412,
#  918968,
#  1010493,
#  1007437,
#  974709,
#  980766,
#  1007716,
#  967157,
#  1063458,
#  987408,
#  937833,
#  920049,
#  940794,
#  915440,
#  974457,
#  1007751,
#  980818,
#  1034389,
#  936538,
#  976098,
#  978613,
#  1011898,
#  970221,
#  939197,
#  986975,
#  983808,
#  1016965,
#  1000022,
#  985090,
#  969493,
#  1021612,
#  963234,
#  949700,
#  1012753,
#  980452,
#  993354,
#  1032482,
#  1020777,
#  996025,
#  980806,
#  1018922,
#  1036146,
#  995906,
#  949352,
#  980194,
#  1053275,
#  966920,
#  990205,
#  996279,
#  935801,
#  1026671,
#  1021704,
#  989425,
#  992512,
#  938906,
#  1074400,
#  944364,
#  1049380,
#  1007819,
#  931660,
#  973513,
#  975642,
#  1035630,
#  1010481,
#  1039517,
#  1034471,
#  977001,
#  970714,
#  881861,
#  1010437,
#  884511,
#  939493,
#  943483,
#  916840,
#  1001472,
#  1029869,
#  1016247,
#  976782,
#  999980,
#  948880,
#  992102,
#  989221,
#  1048683,
#  1049455,
#  960130,
#  982796,
#  1007910,
#  953218,
#  975527,
#  973733,
#  944892,
#  980977,
#  935575,
#  944401,
#  1008688,
#  982863,
#  980278,
#  983154,
#  1018945,
#  906398,
#  1011928,
#  972610,
#  1023909,
#  1043658,
#  1014151,
#  973045,
#  1017939,
#  937961,
#  949371,
#  961285,
#  981920,
#  974422,
#  946356,
#  1019742,
#  986177,
#  984992,
#  905843,
#  963265,
#  967583,
#  929728,
#  979596,
#  957473,
#  1039477,
#  1053637,
#  986615,
#  1022179,
#  993355,
#  996312,
#  968038,
#  1023012,
#  986651,
#  935001,
#  937126,
#  1060651,
#  954139,
#  1054482,
#  1056316,
#  987614,
#  931965,
#  1011938,
#  1033640,
#  975308,
#  935272,
#  1009613,
#  929486,
#  967426,
#  993781,
#  914390,
#  1021598,
#  943551,
#  1002087,
#  929267,
#  991696,
#  1022643,
#  1071368,
#  991839,
#  1009606,
#  1027822,
#  1059391,
#  989265,
#  962467,
#  1015592,
#  1021318,
#  1050238,
#  931007,
#  962305,
#  1005042,
#  989889,
#  981769,
#  1005982,
#  994690,
#  995968,
#  1039498,
#  990363,
#  1018558,
#  934240,
#  1056831,
#  966664,
#  987487,
#  1003636,
#  1022659,
#  975045,
#  1033341,
#  946974,
#  982612,
#  984016,
#  943742,
#  926942,
#  976752,
#  959144,
#  932802,
#  1071970,
#  1003421,
#  1007026,
#  910995,
#  1000904,
#  922156,
#  969266,
#  945908,
#  959421,
#  996289,
#  994102,
#  963753,
#  1030469,
#  890602,
#  1009002,
#  995316,
#  912772,
#  954110,
#  1004752,
#  942465,
#  948041,
#  949129,
#  952808,
#  1079061,
#  1010633,
#  961210,
#  949847,
#  986788,
#  1020373,
#  960475,
#  970747,
#  1001218,
#  997766,
#  1005972,
#  1003852,
#  990017,
#  948100,
#  921263,
#  958338,
#  1025539,
#  952866,
#  992391,
#  902712,
#  980298,
#  974267,
#  1011378,
#  950176,
#  1049200,
#  982882,
#  991919,
#  979911,
#  961698,
#  1023453,
#  976585,
#  898813,
#  988288,
#  1023993,
#  936917,
#  965952,
#  918002,
#  947104,
#  1007298,
#  1002649,
#  922797,
#  1046115,
#  1015919,
#  961090,
#  998675,
#  1013360,
#  1010750,
#  1013356,
#  913588,
#  1012549,
#  930250,
#  1018927,
#  1075898,
#  983302,
#  979904,
#  936161,
#  997176,
#  961616,
#  1022076,
#  972954,
#  899209,
#  944662,
#  973737,
#  934160,
#  992192,
#  977678,
#  879884,
#  1059799,
#  1077507,
#  937677,
#  1012931,
#  1016944,
#  902890,
#  947863,
#  956390,
#  947170,
#  984909,
#  1003761,
#  1036256,
#  1002709,
#  930908,
#  991640,
#  1009434,
#  988953,
#  978535,
#  983497,
#  925528,
#  955040,
#  986031,
#  1047976,
#  875530,
#  935152,
#  1014712,
#  1033773,
#  1053587,
#  941084,
#  973165,
#  908399,
#  975854,
#  954563,
#  957664,
#  982103,
#  928823,
#  1063106,
#  1006374,
#  947070,
#  971705,
#  979839,
#  1023315,
#  948825,
#  963168,
#  1042377,
#  883949,
#  992561,
#  958261,
#  955877,
#  989535,
#  897303,
#  1063304,
#  906093,
#  956406,
#  1011192,
#  976922,
#  1045941,
#  994366,
#  978559,
#  972697,
#  988212,
#  931999,
#  936113,
#  1037483,
#  995453,
#  1080561,
#  957990,
#  1014372,
#  1006929,
#  950090,
#  1001272,
#  963427,
#  946762,
#  941224,
#  1007499,
#  940355,
#  964161,
#  1003248,
#  989914,
#  1020864,
#  1030233,
#  915820,
#  962905,
#  1006176,
#  936719,
#  955908,
#  999147,
#  999169,
#  957449,
#  931154,
#  907321,
#  1038920,
#  988449,
#  1029816,
#  1013226,
#  973552,
#  1025735,
#  1032088,
#  992862,
#  950110,
#  952085,
#  956504,
#  911312,
#  1010900,
#  1082752,
#  943056,
#  989412,
#  977986,
#  938039,
#  971537,
#  958821,
#  986922,
#  902583,
#  1015345,
#  1055958,
#  1040607,
#  945750,
#  926779,
#  969293,
#  902397,
#  912780,
#  988796,
#  904695,
#  956226,
#  1044612,
#  1046142,
#  980557,
#  996386,
#  938287,
#  944571,
#  903781,
#  899374,
#  981486,
#  1005850,
#  924052,
#  931395,
#  1065401,
#  1026967,
#  1039999,
#  1010908,
#  1015574,
#  972503,
#  1002655,
#  1016483,
#  951830,
#  1016485,
#  969581,
#  954861,
#  981083,
#  1045105,
#  985225,
#  943347,
#  996800,
#  1006062,
#  1026426,
#  1004683,
#  968370,
#  922163,
#  1021259,
#  982101,
#  964362,
#  936234,
#  1002769,
#  931768,
#  939680,
#  970686,
#  944285,
#  943560,
#  1037947,
#  1060608,
#  971307,
#  1018509,
#  938432,
#  977308,
#  906676,
#  1010586,
#  955050,
#  1004220,
#  975846,
#  1007233,
#  982659,
#  938968,
#  986706,
#  1033164,
#  949721,
#  936778,
#  1002542,
#  956451,
#  947820,
#  992387,
#  1050561,
#  979635,
#  917090,
#  996110,
#  1063556,
#  1008034,
#  1004961,
#  963853,
#  986338,
#  1013537,
#  966025,
#  993305,
#  920272,
#  941438,
#  958446,
#  998125,
#  957487,
#  1048475,
#  990337,
#  959776,
#  957115,
#  1006161,
#  954143,
#  977084,
#  1015306,
#  990620,
#  1010633,
#  1029422,
#  1083700,
#  993086,
#  942044,
#  926804,
#  947090,
#  1043074,
#  958774,
#  1029836,
#  987004,
#  923024,
#  1057146,
#  1004049,
#  1051335,
#  1028618,
#  ...]

# %%
min(distances)
# Out:
# 818494

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(16, 8))
plt.subplot(1, 2, 1)
plt.hist(distances)

plt.xlabel('Distribution')
plt.ylabel('Distance')
plt.title("Distribution vs Distance")

plt.subplot(1, 2, 2)
plt.hist2d([i for i in range(10000)], distances, bins=(300, 300), cmap=plt.cm.jet)
plt.xlabel('Distance')
plt.ylabel('Distribution')
plt.title("Distribution vs Distance")

plt.show()
